# %% [markdown]
# ### Configurar semestre actual

# %%
archivo_json = "2025-2"

# %% [markdown]
# ### Utilidades

# %%
import re
from html import unescape

def extract_description(program_str: str) -> str:
    # Limpia etiquetas HTML y caracteres especiales
    clean = re.sub(r'<[^>]+>', '', program_str)
    clean = unescape(clean)

    # Unifica saltos de línea y quita espacios de más
    clean = re.sub(r'\r\n?|\n', '\n', clean)
    clean = re.sub(r'\t+', ' ', clean)

    # Busca secciones como "I. DESCRIPCIÓN", "II.DESCRIPCION", etc.
    pattern = re.compile(r"(?m)^([IVXLCDM]+)[\.\s]+(.{3,100})$")

    matches = list(pattern.finditer(clean))

    for i, match in enumerate(matches):
        title = match.group(2).upper()
        if "DESCRIPCION" in title or "DESCRIPCIÓN" in title:
            start = match.end()
            end = matches[i + 1].start() if i + 1 < len(matches) else len(clean)
            return clean[start:end].strip()

    return ""

# %% [markdown]
# ### Unir todos los semestres en 1
# Esto es para generar el `cursos-simplificado.json`, que son los cursos que alguna vez se han dado en la universidad

# %%
##
# SI TIENE UN NUEVO ARCHIVO JSON, DEBE SER AGREGADO AQUÍ
# ACTUALMENTE, LOS ARCHIVOS JSON SON:
# - 2025-2.json
# - 2025-1.json 
# - 2024-3.json // El 3 es TAV
# - 2024-2.json
##

import json

with open("2025-2.json", "r", encoding="utf-8") as f:
    data_2025_2 = json.load(f)
for i in data_2025_2:
    data_2025_2[i]["last_semester"] = "2025-2"

with open("2025-1.json", "r", encoding="utf-8") as f:
    data_2025_1 = json.load(f)
for i in data_2025_1:
    data_2025_1[i]["last_semester"] = "2025-1"

with open("2024-3.json", "r", encoding="utf-8") as f:
    data_2024_3 = json.load(f)
for i in data_2024_3:
    data_2024_3[i]["last_semester"] = "2024-3"

with open("2024-2.json", "r", encoding="utf-8") as f:
    data_2024_2 = json.load(f)
for i in data_2024_2:
    data_2024_2[i]["last_semester"] = "2024-2"

# Combinamos: 2024-2 primero, y luego sobrescribimos con 2025-1
combined_data = data_2024_2.copy()
combined_data.update(data_2024_3)
combined_data.update(data_2025_1)  # sobrescribe duplicados con los de 2025-1
combined_data.update(data_2025_2)  # sobrescribe duplicados con los de 2025-2

# %%
simplified_data = {}

for code, course in combined_data.items():
    sections = course.get("sections", {})
    
    # Agrupar valores únicos de secciones
    formats = set()
    campuses = set()
    is_removable = set()
    is_special = set()
    is_english = set()
    categories = set()

    for section in sections.values():
        formats.add(section.get("format"))
        campuses.add(section.get("campus"))
        is_removable.add(section.get("is_removable"))
        is_special.add(section.get("is_special"))
        is_english.add(section.get("is_english"))
        categories.add(section.get("category", ""))
    
    # Extraer descripción del programa
    program_raw = course.get("program", "")
    description = extract_description(program_raw)

    simplified_data[code] = {
        "sigle": code,
        "name": course["name"],
        "credits": course["credits"],
        "req": course["req"],
        "conn": course["conn"],
        "restr": course["restr"],
        "equiv": course["equiv"],
        "school": course["school"],
        "area": course.get("area", ""),
        "categories": list(categories),
        "format": list(formats),
        "campus": list(campuses),
        "is_removable": list(is_removable),
        "is_special": list(is_special),
        "is_english": list(is_english),
        "description": description,
        "last_semester": course["last_semester"]
    }

    if description == "" and program_raw != "Programa de curso no disponible":
        print(f"Advertencia: No se encontró descripción para el curso {code}")

simplified_data["OSUC500"] = {
    "sigle": "OSUC500",
    "name": "Busca Ramos Feedback",
    "credits": -10,
    "req": "",
    "conn": "",
    "restr": "",
    "equiv": "",
    "school": "OSUC",
    "area": "",
    "category": "",
    "format": ["Presencial"],
    "campus": ["San Joaquín", "Oriente", "Villarrica", "Casa Central", "Lo Contador"],
    "is_removable": [False],
    "is_special": [False],
    "is_english": [False],
    "description": "¿Tienes comentarios o sugerencias? Este es tu espacio para compartir críticas y ayudarnos a mejorar el contenido de Busca Ramos. ¡Tu opinión cuenta!",
    "last_semester": archivo_json,
    "categories": ["Feedback", "Mejora Continua"]
}
# Guardar resultado
with open("cursos-simplificado.json", "w", encoding="utf-8") as f:
    json.dump(simplified_data, f, ensure_ascii=False, indent=2)
# Out:
# Advertencia: No se encontró descripción para el curso ACO4001
# Advertencia: No se encontró descripción para el curso ACO4002
# Advertencia: No se encontró descripción para el curso AGP4020
# Advertencia: No se encontró descripción para el curso ARO105D
# Advertencia: No se encontró descripción para el curso AST0112
# Advertencia: No se encontró descripción para el curso ASP5406
# Advertencia: No se encontró descripción para el curso BIO231C
# Advertencia: No se encontró descripción para el curso COM024
# Advertencia: No se encontró descripción para el curso COM601
# Advertencia: No se encontró descripción para el curso DDE3147
# Advertencia: No se encontró descripción para el curso DER501S
# Advertencia: No se encontró descripción para el curso DER503G
# Advertencia: No se encontró descripción para el curso DMD3925
# Advertencia: No se encontró descripción para el curso EAA2095
# Advertencia: No se encontró descripción para el curso EAA3230
# Advertencia: No se encontró descripción para el curso EAE4105
# Advertencia: No se encontró descripción para el curso EAM321
# Advertencia: No se encontró descripción para el curso EAM344
# Advertencia: No se encontró descripción para el curso EAM450
# Advertencia: No se encontró descripción para el curso EAM667
# Advertencia: No se encontró descripción para el curso EAM668
# Advertencia: No se encontró descripción para el curso EDU0508
# Advertencia: No se encontró descripción para el curso EDU0509
# Advertencia: No se encontró descripción para el curso EDU4035
# Advertencia: No se encontró descripción para el curso EDU4060
# Advertencia: No se encontró descripción para el curso EDU4061
# Advertencia: No se encontró descripción para el curso EDU4062
# Advertencia: No se encontró descripción para el curso EDU4205
# Advertencia: No se encontró descripción para el curso EDU4222
# Advertencia: No se encontró descripción para el curso EDU4225
# Advertencia: No se encontró descripción para el curso EIN1003
# Advertencia: No se encontró descripción para el curso EIN1005
# Advertencia: No se encontró descripción para el curso EIN1006
# Advertencia: No se encontró descripción para el curso EIN1009
# Advertencia: No se encontró descripción para el curso EIN1010
# Advertencia: No se encontró descripción para el curso ENF1126
# Advertencia: No se encontró descripción para el curso EPG3311
# Advertencia: No se encontró descripción para el curso EPG3317
# Advertencia: No se encontró descripción para el curso EPG3322
# Advertencia: No se encontró descripción para el curso ESO2663
# Advertencia: No se encontró descripción para el curso EYP2310
# Advertencia: No se encontró descripción para el curso FIM8203
# Advertencia: No se encontró descripción para el curso FIZ0211
# Advertencia: No se encontró descripción para el curso FIZ0221
# Advertencia: No se encontró descripción para el curso FIZ0222
# Advertencia: No se encontró descripción para el curso FIZ0223
# Advertencia: No se encontró descripción para el curso FIZ0311
# Advertencia: No se encontró descripción para el curso FIZ0312
# Advertencia: No se encontró descripción para el curso FIZ0321
# Advertencia: No se encontró descripción para el curso FIZ0322
# Advertencia: No se encontró descripción para el curso FIZ0511
# Advertencia: No se encontró descripción para el curso FIZ2800
# Advertencia: No se encontró descripción para el curso FIL113T
# Advertencia: No se encontró descripción para el curso FIL114T
# Advertencia: No se encontró descripción para el curso FIL116T
# Advertencia: No se encontró descripción para el curso FIL117T
# Advertencia: No se encontró descripción para el curso FIL209T
# Advertencia: No se encontró descripción para el curso FMD3019
# Advertencia: No se encontró descripción para el curso ICC3272
# Advertencia: No se encontró descripción para el curso IBM3102
# Advertencia: No se encontró descripción para el curso IBM3104
# Advertencia: No se encontró descripción para el curso IBM3106
# Advertencia: No se encontró descripción para el curso IBM3111
# Advertencia: No se encontró descripción para el curso IBM3112
# Advertencia: No se encontró descripción para el curso IBM3113
# Advertencia: No se encontró descripción para el curso IBM3120
# Advertencia: No se encontró descripción para el curso IBM3121
# Advertencia: No se encontró descripción para el curso IBM3122
# Advertencia: No se encontró descripción para el curso IBM3123
# Advertencia: No se encontró descripción para el curso IBM3124
# Advertencia: No se encontró descripción para el curso IBM3125
# Advertencia: No se encontró descripción para el curso IBM3126
# Advertencia: No se encontró descripción para el curso IBM3127
# Advertencia: No se encontró descripción para el curso IBM3128
# Advertencia: No se encontró descripción para el curso IBM3129
# Advertencia: No se encontró descripción para el curso IBM3130
# Advertencia: No se encontró descripción para el curso ICT3212
# Advertencia: No se encontró descripción para el curso ICT3256
# Advertencia: No se encontró descripción para el curso ICT3333
# Advertencia: No se encontró descripción para el curso ICM3532
# Advertencia: No se encontró descripción para el curso ICS3313
# Advertencia: No se encontró descripción para el curso ICS3742
# Advertencia: No se encontró descripción para el curso ICP5703
# Advertencia: No se encontró descripción para el curso ICP5928
# Advertencia: No se encontró descripción para el curso ICP5929
# Advertencia: No se encontró descripción para el curso IEE2213
# Advertencia: No se encontró descripción para el curso IEE2463
# Advertencia: No se encontró descripción para el curso IEE3682
# Advertencia: No se encontró descripción para el curso IEE3733
# Advertencia: No se encontró descripción para el curso IEE3773
# Advertencia: No se encontró descripción para el curso IDT3000
# Advertencia: No se encontró descripción para el curso IDT3010
# Advertencia: No se encontró descripción para el curso IDT4941
# Advertencia: No se encontró descripción para el curso IDT4942
# Advertencia: No se encontró descripción para el curso IHI0225
# Advertencia: No se encontró descripción para el curso IIQ3652
# Advertencia: No se encontró descripción para el curso IIQ3662
# Advertencia: No se encontró descripción para el curso IIC1062
# Advertencia: No se encontró descripción para el curso IIC2562
# Advertencia: No se encontró descripción para el curso IIC3380
# Advertencia: No se encontró descripción para el curso IIC3686
# Advertencia: No se encontró descripción para el curso IIC3733
# Advertencia: No se encontró descripción para el curso IIC3783
# Advertencia: No se encontró descripción para el curso ILS1321
# Advertencia: No se encontró descripción para el curso ILS1322
# Advertencia: No se encontró descripción para el curso ILS1323
# Advertencia: No se encontró descripción para el curso ILS1325
# Advertencia: No se encontró descripción para el curso ILS1326
# Advertencia: No se encontró descripción para el curso ILS1327
# Advertencia: No se encontró descripción para el curso IMM1003
# Advertencia: No se encontró descripción para el curso IND3920
# Advertencia: No se encontró descripción para el curso INF3580
# Advertencia: No se encontró descripción para el curso KIN501A
# Advertencia: No se encontró descripción para el curso LET007I
# Advertencia: No se encontró descripción para el curso LET049I
# Advertencia: No se encontró descripción para el curso LET1313
# Advertencia: No se encontró descripción para el curso LET1314
# Advertencia: No se encontró descripción para el curso LET1318
# Advertencia: No se encontró descripción para el curso LET1326
# Advertencia: No se encontró descripción para el curso LET1332
# Advertencia: No se encontró descripción para el curso LET1348
# Advertencia: No se encontró descripción para el curso LET1351
# Advertencia: No se encontró descripción para el curso LET1367
# Advertencia: No se encontró descripción para el curso LET211I
# Advertencia: No se encontró descripción para el curso LET212I
# Advertencia: No se encontró descripción para el curso LET2312
# Advertencia: No se encontró descripción para el curso LET4473
# Advertencia: No se encontró descripción para el curso MAT2805
# Advertencia: No se encontró descripción para el curso MPG3101
# Advertencia: No se encontró descripción para el curso MPG3201
# Advertencia: No se encontró descripción para el curso MPG3950
# Advertencia: No se encontró descripción para el curso MSG3013
# Advertencia: No se encontró descripción para el curso MSG3014
# Advertencia: No se encontró descripción para el curso ODO407A
# Advertencia: No se encontró descripción para el curso PSB408
# Advertencia: No se encontró descripción para el curso PSI3505
# Advertencia: No se encontró descripción para el curso QIM115
# Advertencia: No se encontró descripción para el curso QIM116
# Advertencia: No se encontró descripción para el curso RII8001
# Advertencia: No se encontró descripción para el curso RII8002
# Advertencia: No se encontró descripción para el curso RII8003
# Advertencia: No se encontró descripción para el curso SOL116
# Advertencia: No se encontró descripción para el curso SOL135
# Advertencia: No se encontró descripción para el curso SOL152S
# Advertencia: No se encontró descripción para el curso TBH040
# Advertencia: No se encontró descripción para el curso TBI012
# Advertencia: No se encontró descripción para el curso TBI021
# Advertencia: No se encontró descripción para el curso TEO3009
# Advertencia: No se encontró descripción para el curso TEO3010
# Advertencia: No se encontró descripción para el curso TTF229
# Advertencia: No se encontró descripción para el curso TTF231
# Advertencia: No se encontró descripción para el curso VIL622
# Advertencia: No se encontró descripción para el curso VIL623
# Advertencia: No se encontró descripción para el curso VIL624
# Advertencia: No se encontró descripción para el curso VIL625
# Advertencia: No se encontró descripción para el curso VIL626
# Advertencia: No se encontró descripción para el curso AGL023
# Advertencia: No se encontró descripción para el curso EAM677
# Advertencia: No se encontró descripción para el curso ACO4004
# Advertencia: No se encontró descripción para el curso ANT160
# Advertencia: No se encontró descripción para el curso BIO272C
# Advertencia: No se encontró descripción para el curso DDE3146
# Advertencia: No se encontró descripción para el curso DER504G
# Advertencia: No se encontró descripción para el curso DMD3156
# Advertencia: No se encontró descripción para el curso EAE120S
# Advertencia: No se encontró descripción para el curso EAE305
# Advertencia: No se encontró descripción para el curso EAM303
# Advertencia: No se encontró descripción para el curso EAM340
# Advertencia: No se encontró descripción para el curso EIN1001
# Advertencia: No se encontró descripción para el curso EIN1002
# Advertencia: No se encontró descripción para el curso EIN1004
# Advertencia: No se encontró descripción para el curso EIN1007
# Advertencia: No se encontró descripción para el curso EIN1008
# Advertencia: No se encontró descripción para el curso EDU0506
# Advertencia: No se encontró descripción para el curso EDU0507
# Advertencia: No se encontró descripción para el curso EDU4220
# Advertencia: No se encontró descripción para el curso EDU4221
# Advertencia: No se encontró descripción para el curso EDU4224
# Advertencia: No se encontró descripción para el curso EPG3307
# Advertencia: No se encontró descripción para el curso EPG3313
# Advertencia: No se encontró descripción para el curso ESO2811
# Advertencia: No se encontró descripción para el curso EST3000
# Advertencia: No se encontró descripción para el curso EUC8002
# Advertencia: No se encontró descripción para el curso FIZ0121
# Advertencia: No se encontró descripción para el curso FIZ020C
# Advertencia: No se encontró descripción para el curso FIZ0313
# Advertencia: No se encontró descripción para el curso FIZ0411
# Advertencia: No se encontró descripción para el curso FIZ0412
# Advertencia: No se encontró descripción para el curso FIZ1436
# Advertencia: No se encontró descripción para el curso FIL111T
# Advertencia: No se encontró descripción para el curso FIL112T
# Advertencia: No se encontró descripción para el curso FIL115T
# Advertencia: No se encontró descripción para el curso FIL119T
# Advertencia: No se encontró descripción para el curso FIL122T
# Advertencia: No se encontró descripción para el curso FIL213T
# Advertencia: No se encontró descripción para el curso FMD3006
# Advertencia: No se encontró descripción para el curso IBM3101
# Advertencia: No se encontró descripción para el curso IBM3103
# Advertencia: No se encontró descripción para el curso IBM3105
# Advertencia: No se encontró descripción para el curso ICH3532
# Advertencia: No se encontró descripción para el curso ICC2312
# Advertencia: No se encontró descripción para el curso ICC3253
# Advertencia: No se encontró descripción para el curso ICM3534
# Advertencia: No se encontró descripción para el curso ICM3762
# Advertencia: No se encontró descripción para el curso ICS113H
# Advertencia: No se encontró descripción para el curso ICS3252
# Advertencia: No se encontró descripción para el curso ICS3582
# Advertencia: No se encontró descripción para el curso IDT3020
# Advertencia: No se encontró descripción para el curso ICP5930
# Advertencia: No se encontró descripción para el curso IEE2224
# Advertencia: No se encontró descripción para el curso IEE2343
# Advertencia: No se encontró descripción para el curso IEE3732
# Advertencia: No se encontró descripción para el curso IEU3025
# Advertencia: No se encontró descripción para el curso IEU3047
# Advertencia: No se encontró descripción para el curso IEU5000
# Advertencia: No se encontró descripción para el curso IIQ3402
# Advertencia: No se encontró descripción para el curso IIQ3602
# Advertencia: No se encontró descripción para el curso IIC2552
# Advertencia: No se encontró descripción para el curso IIC3242
# Advertencia: No se encontró descripción para el curso IIC3753
# Advertencia: No se encontró descripción para el curso ILS1324
# Advertencia: No se encontró descripción para el curso LET018I
# Advertencia: No se encontró descripción para el curso LET1331
# Advertencia: No se encontró descripción para el curso LET1333
# Advertencia: No se encontró descripción para el curso LET1341
# Advertencia: No se encontró descripción para el curso LET2311
# Advertencia: No se encontró descripción para el curso LET2313
# Advertencia: No se encontró descripción para el curso LET2315
# Advertencia: No se encontró descripción para el curso LET236E
# Advertencia: No se encontró descripción para el curso LET3111
# Advertencia: No se encontró descripción para el curso MBC3001
# Advertencia: No se encontró descripción para el curso MMM1002
# Advertencia: No se encontró descripción para el curso MPG3100
# Advertencia: No se encontró descripción para el curso MPG3200
# Advertencia: No se encontró descripción para el curso MSP3027
# Advertencia: No se encontró descripción para el curso PSI3506
# Advertencia: No se encontró descripción para el curso SOL119
# Advertencia: No se encontró descripción para el curso SOL131
# Advertencia: No se encontró descripción para el curso SUS2111
# Advertencia: No se encontró descripción para el curso TBJ043
# Advertencia: No se encontró descripción para el curso TBI011
# Advertencia: No se encontró descripción para el curso TBI013
# Advertencia: No se encontró descripción para el curso TBI022
# Advertencia: No se encontró descripción para el curso EAM2062
# Advertencia: No se encontró descripción para el curso EAM2063
# Advertencia: No se encontró descripción para el curso EAE102S
# Advertencia: No se encontró descripción para el curso ICH3270
# Advertencia: No se encontró descripción para el curso ICM3918
# Advertencia: No se encontró descripción para el curso TBI023
# Advertencia: No se encontró descripción para el curso DER502G
# Advertencia: No se encontró descripción para el curso DER509G
# Advertencia: No se encontró descripción para el curso LET033I
# Advertencia: No se encontró descripción para el curso LET075I
# Advertencia: No se encontró descripción para el curso LET4475
# Advertencia: No se encontró descripción para el curso IIC3192

# %%
len(combined_data)
# Out:
# 7323

# %% [markdown]
# # SQL parser
# Pasar los datos a un **.sql** para poder subirlos a bdd (Busca Ramos formato)

# %%
import os

# Generar sentencias SQL para course_summary
sql_statements = []

for course in simplified_data.values():
    sigle = course["sigle"]

    columns = [
        "sigle",
        "likes",
        "superlikes",
        "dislikes",
        "votes_low_workload",
        "votes_medium_workload",
        "votes_high_workload",
        "votes_mandatory_attendance",
        "votes_optional_attendance",
        "avg_weekly_hours",
        "sort_index"
    ]

    # Valores iniciales por defecto
    values = [
        f"'{sigle}'",
        "0", "0", "0",         # likes, superlikes, dislikes
        "0", "0", "0",         # workload votes
        "0", "0",              # attendance votes
        "0.0",                 # avg_weekly_hours
        "0"                   # sort_index
    ]

    updates = [f"{col}=EXCLUDED.{col}" for col in columns if col != "sigle"]

    sql = (
        f"INSERT INTO course_summary ({', '.join(columns)})\n"
        f"VALUES ({', '.join(values)})\n"
        f"ON CONFLICT (sigle) DO NOTHING;"
    )

    sql_statements.append(sql)

# Crear carpeta de salida
os.makedirs("sql_output", exist_ok=True)

# Escribir en archivos de 100 sentencias cada uno
for i in range(0, len(sql_statements), 100):
    chunk = sql_statements[i:i + 100]
    file_index = (i // 100) + 1
    with open(f"sql_output/{file_index}.sql", "w", encoding="utf-8") as f:
        f.write("\n\n".join(chunk))

print(f"✅ {((len(sql_statements) - 1) // 100) + 1} archivos SQL generados en carpeta 'sql_output/' para 'course_summary'")
# Out:
# ✅ 74 archivos SQL generados en carpeta 'sql_output/' para 'course_summary'

# %% [markdown]
# ### Obtener la informacion de **solo las secciones del semestre configurado**

# %%
import json

# Cargar datos desde el archivo JSON
with open(f"{archivo_json}.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Escribir archivo NDJSON con solo 'sigle', 'sections' y 'name'
with open(f"courses-sections.ndjson", "w", encoding="utf-8") as f:
    for curso in data.values():
        ndjson_obj = {
            "sigle": curso.get("sigle"),
            "sections": curso.get("sections"),
            "name": curso.get("name"),
        }
        f.write(json.dumps(ndjson_obj, ensure_ascii=False) + "\n")
